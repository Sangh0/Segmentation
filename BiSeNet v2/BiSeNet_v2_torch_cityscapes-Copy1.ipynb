# %% [markdown]
# # BiSeNet v2 구현
# - pytorch

# %%
import os
import time
import random
import warnings
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image
from tqdm.notebook import tqdm

import albumentations as A
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
import torch.utils.model_zoo as modelzoo
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary

from torchcallback import EarlyStopping, CheckPoint
from torchlosses import OhemCELoss
from torchmetrics import Metrics
from torchscheduler import PolynomialLRDecay
from torchtransform import RandomCrop, HorizontalFlip, RandomScale, ColorJitter, Compose

from model import BiSeNetV2
from cityscapes import CityscapesDataset
from train import train_step

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10,7]

# %% [markdown]
# # Load Data

# %%
width = 1024
height = 512
num_classes = 19

# cuda setting
device = torch.device('cuda')
print(device)
# Out:
# cuda

# %%
path = 'C:/Users/user/MY_DL/segmentation/dataset/cityscapes'

batch_size = 16

train_loader = DataLoader(
    CityscapesDataset(path=path, subset='train', cropsize=(width,height)),
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

valid_loader = DataLoader(
    CityscapesDataset(path=path, subset='valid', cropsize=(width,height)),
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

# %% [markdown]
# # Model

# %%
summary(BiSeNetV2(num_classes=num_classes), (3, height, width), device='cpu')
model = BiSeNetV2(num_classes=num_classes).to(device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 256, 512]           1,728
#        BatchNorm2d-2         [-1, 64, 256, 512]             128
#               ReLU-3         [-1, 64, 256, 512]               0
#          ConvBlock-4         [-1, 64, 256, 512]               0
#             Conv2d-5         [-1, 64, 256, 512]          36,864
#        BatchNorm2d-6         [-1, 64, 256, 512]             128
#               ReLU-7         [-1, 64, 256, 512]               0
#          ConvBlock-8         [-1, 64, 256, 512]               0
#             Conv2d-9         [-1, 64, 128, 256]          36,864
#       BatchNorm2d-10         [-1, 64, 128, 256]             128
#              ReLU-11         [-1, 64, 128, 256]               0
#         ConvBlock-12         [-1, 64, 128, 256]               0
#            Conv2d-13         [-1, 64, 128, 256]          36,864
#       BatchNorm2d-14         [-1, 64, 128, 256]             128
#              ReLU-15         [-1, 64, 128, 256]               0
#         ConvBlock-16         [-1, 64, 128, 256]               0
#            Conv2d-17         [-1, 64, 128, 256]          36,864
#       BatchNorm2d-18         [-1, 64, 128, 256]             128
#              ReLU-19         [-1, 64, 128, 256]               0
#         ConvBlock-20         [-1, 64, 128, 256]               0
#            Conv2d-21         [-1, 128, 64, 128]          73,728
#       BatchNorm2d-22         [-1, 128, 64, 128]             256
#              ReLU-23         [-1, 128, 64, 128]               0
#         ConvBlock-24         [-1, 128, 64, 128]               0
#            Conv2d-25         [-1, 128, 64, 128]         147,456
#       BatchNorm2d-26         [-1, 128, 64, 128]             256
#              ReLU-27         [-1, 128, 64, 128]               0
#         ConvBlock-28         [-1, 128, 64, 128]               0
#            Conv2d-29         [-1, 128, 64, 128]         147,456
#       BatchNorm2d-30         [-1, 128, 64, 128]             256
#              ReLU-31         [-1, 128, 64, 128]               0
#         ConvBlock-32         [-1, 128, 64, 128]               0
#      DetailBranch-33         [-1, 128, 64, 128]               0
#            Conv2d-34         [-1, 16, 256, 512]             432
#       BatchNorm2d-35         [-1, 16, 256, 512]              32
#              ReLU-36         [-1, 16, 256, 512]               0
#         ConvBlock-37         [-1, 16, 256, 512]               0
#            Conv2d-38          [-1, 8, 256, 512]             128
#       BatchNorm2d-39          [-1, 8, 256, 512]              16
#              ReLU-40          [-1, 8, 256, 512]               0
#         ConvBlock-41          [-1, 8, 256, 512]               0
#            Conv2d-42         [-1, 16, 128, 256]           1,152
#       BatchNorm2d-43         [-1, 16, 128, 256]              32
#              ReLU-44         [-1, 16, 128, 256]               0
#         ConvBlock-45         [-1, 16, 128, 256]               0
#         MaxPool2d-46         [-1, 16, 128, 256]               0
#            Conv2d-47         [-1, 16, 128, 256]           4,608
#       BatchNorm2d-48         [-1, 16, 128, 256]              32
#              ReLU-49         [-1, 16, 128, 256]               0
#         ConvBlock-50         [-1, 16, 128, 256]               0
#         StemBlock-51         [-1, 16, 128, 256]               0
#            Conv2d-52         [-1, 16, 128, 256]           2,304
#       BatchNorm2d-53         [-1, 16, 128, 256]              32
#              ReLU-54         [-1, 16, 128, 256]               0
#         ConvBlock-55         [-1, 16, 128, 256]               0
#            Conv2d-56          [-1, 96, 64, 128]             864
#       BatchNorm2d-57          [-1, 96, 64, 128]             192
#            Conv2d-58          [-1, 96, 64, 128]             864
#       BatchNorm2d-59          [-1, 96, 64, 128]             192
#              ReLU-60          [-1, 96, 64, 128]               0
#            Conv2d-61          [-1, 32, 64, 128]           3,072
#       BatchNorm2d-62          [-1, 32, 64, 128]              64
#            Conv2d-63          [-1, 16, 64, 128]             144
#       BatchNorm2d-64          [-1, 16, 64, 128]              32
#            Conv2d-65          [-1, 32, 64, 128]             512
#       BatchNorm2d-66          [-1, 32, 64, 128]              64
#              ReLU-67          [-1, 32, 64, 128]               0
#          GELayer2-68          [-1, 32, 64, 128]               0
#            Conv2d-69          [-1, 32, 64, 128]           9,216
#       BatchNorm2d-70          [-1, 32, 64, 128]              64
#              ReLU-71          [-1, 32, 64, 128]               0
#         ConvBlock-72          [-1, 32, 64, 128]               0
#            Conv2d-73         [-1, 192, 64, 128]           1,728
#       BatchNorm2d-74         [-1, 192, 64, 128]             384
#              ReLU-75         [-1, 192, 64, 128]               0
#            Conv2d-76          [-1, 32, 64, 128]           6,144
#       BatchNorm2d-77          [-1, 32, 64, 128]              64
#              ReLU-78          [-1, 32, 64, 128]               0
#          GELayer1-79          [-1, 32, 64, 128]               0
#            Conv2d-80          [-1, 32, 64, 128]           9,216
#       BatchNorm2d-81          [-1, 32, 64, 128]              64
#              ReLU-82          [-1, 32, 64, 128]               0
#         ConvBlock-83          [-1, 32, 64, 128]               0
#            Conv2d-84          [-1, 192, 32, 64]           1,728
#       BatchNorm2d-85          [-1, 192, 32, 64]             384
#            Conv2d-86          [-1, 192, 32, 64]           1,728
#       BatchNorm2d-87          [-1, 192, 32, 64]             384
#              ReLU-88          [-1, 192, 32, 64]               0
#            Conv2d-89           [-1, 64, 32, 64]          12,288
#       BatchNorm2d-90           [-1, 64, 32, 64]             128
#            Conv2d-91           [-1, 32, 32, 64]             288
#       BatchNorm2d-92           [-1, 32, 32, 64]              64
#            Conv2d-93           [-1, 64, 32, 64]           2,048
#       BatchNorm2d-94           [-1, 64, 32, 64]             128
#              ReLU-95           [-1, 64, 32, 64]               0
#          GELayer2-96           [-1, 64, 32, 64]               0
#            Conv2d-97           [-1, 64, 32, 64]          36,864
#       BatchNorm2d-98           [-1, 64, 32, 64]             128
#              ReLU-99           [-1, 64, 32, 64]               0
#        ConvBlock-100           [-1, 64, 32, 64]               0
#           Conv2d-101          [-1, 384, 32, 64]           3,456
#      BatchNorm2d-102          [-1, 384, 32, 64]             768
#             ReLU-103          [-1, 384, 32, 64]               0
#           Conv2d-104           [-1, 64, 32, 64]          24,576
#      BatchNorm2d-105           [-1, 64, 32, 64]             128
#             ReLU-106           [-1, 64, 32, 64]               0
#         GELayer1-107           [-1, 64, 32, 64]               0
#           Conv2d-108           [-1, 64, 32, 64]          36,864
#      BatchNorm2d-109           [-1, 64, 32, 64]             128
#             ReLU-110           [-1, 64, 32, 64]               0
#        ConvBlock-111           [-1, 64, 32, 64]               0
#           Conv2d-112          [-1, 384, 16, 32]           3,456
#      BatchNorm2d-113          [-1, 384, 16, 32]             768
#           Conv2d-114          [-1, 384, 16, 32]           3,456
#      BatchNorm2d-115          [-1, 384, 16, 32]             768
#             ReLU-116          [-1, 384, 16, 32]               0
#           Conv2d-117          [-1, 128, 16, 32]          49,152
#      BatchNorm2d-118          [-1, 128, 16, 32]             256
#           Conv2d-119           [-1, 64, 16, 32]             576
#      BatchNorm2d-120           [-1, 64, 16, 32]             128
#           Conv2d-121          [-1, 128, 16, 32]           8,192
#      BatchNorm2d-122          [-1, 128, 16, 32]             256
#             ReLU-123          [-1, 128, 16, 32]               0
#         GELayer2-124          [-1, 128, 16, 32]               0
#           Conv2d-125          [-1, 128, 16, 32]         147,456
#      BatchNorm2d-126          [-1, 128, 16, 32]             256
#             ReLU-127          [-1, 128, 16, 32]               0
#        ConvBlock-128          [-1, 128, 16, 32]               0
#           Conv2d-129          [-1, 768, 16, 32]           6,912
#      BatchNorm2d-130          [-1, 768, 16, 32]           1,536
#             ReLU-131          [-1, 768, 16, 32]               0
#           Conv2d-132          [-1, 128, 16, 32]          98,304
#      BatchNorm2d-133          [-1, 128, 16, 32]             256
#             ReLU-134          [-1, 128, 16, 32]               0
#         GELayer1-135          [-1, 128, 16, 32]               0
#           Conv2d-136          [-1, 128, 16, 32]         147,456
#      BatchNorm2d-137          [-1, 128, 16, 32]             256
#             ReLU-138          [-1, 128, 16, 32]               0
#        ConvBlock-139          [-1, 128, 16, 32]               0
#           Conv2d-140          [-1, 768, 16, 32]           6,912
#      BatchNorm2d-141          [-1, 768, 16, 32]           1,536
#             ReLU-142          [-1, 768, 16, 32]               0
#           Conv2d-143          [-1, 128, 16, 32]          98,304
#      BatchNorm2d-144          [-1, 128, 16, 32]             256
#             ReLU-145          [-1, 128, 16, 32]               0
#         GELayer1-146          [-1, 128, 16, 32]               0
#           Conv2d-147          [-1, 128, 16, 32]         147,456
#      BatchNorm2d-148          [-1, 128, 16, 32]             256
#             ReLU-149          [-1, 128, 16, 32]               0
#        ConvBlock-150          [-1, 128, 16, 32]               0
#           Conv2d-151          [-1, 768, 16, 32]           6,912
#      BatchNorm2d-152          [-1, 768, 16, 32]           1,536
#             ReLU-153          [-1, 768, 16, 32]               0
#           Conv2d-154          [-1, 128, 16, 32]          98,304
#      BatchNorm2d-155          [-1, 128, 16, 32]             256
#             ReLU-156          [-1, 128, 16, 32]               0
#         GELayer1-157          [-1, 128, 16, 32]               0
# AdaptiveAvgPool2d-158            [-1, 128, 1, 1]               0
#      BatchNorm2d-159            [-1, 128, 1, 1]             256
#           Conv2d-160            [-1, 128, 1, 1]          16,384
#      BatchNorm2d-161            [-1, 128, 1, 1]             256
#             ReLU-162            [-1, 128, 1, 1]               0
#        ConvBlock-163            [-1, 128, 1, 1]               0
#           Conv2d-164          [-1, 128, 16, 32]         147,456
#      BatchNorm2d-165          [-1, 128, 16, 32]             256
#             ReLU-166          [-1, 128, 16, 32]               0
#        ConvBlock-167          [-1, 128, 16, 32]               0
#          CEBlock-168          [-1, 128, 16, 32]               0
#   SemanticBranch-169  [[-1, 16, 128, 256], [-1, 32, 64, 128], [-1, 64, 32, 64], [-1, 128, 16, 32], [-1, 128, 16, 32]]               0
#           Conv2d-170         [-1, 128, 64, 128]           1,152
#      BatchNorm2d-171         [-1, 128, 64, 128]             256
#           Conv2d-172         [-1, 128, 64, 128]          16,384
#           Conv2d-173          [-1, 128, 32, 64]         147,456
#      BatchNorm2d-174          [-1, 128, 32, 64]             256
#        AvgPool2d-175          [-1, 128, 16, 32]               0
#           Conv2d-176          [-1, 128, 16, 32]         147,456
#      BatchNorm2d-177          [-1, 128, 16, 32]             256
#         Upsample-178         [-1, 128, 64, 128]               0
#          Sigmoid-179         [-1, 128, 64, 128]               0
#           Conv2d-180          [-1, 128, 16, 32]           1,152
#      BatchNorm2d-181          [-1, 128, 16, 32]             256
#           Conv2d-182          [-1, 128, 16, 32]          16,384
#          Sigmoid-183          [-1, 128, 16, 32]               0
#         Upsample-184         [-1, 128, 64, 128]               0
#           Conv2d-185         [-1, 128, 64, 128]         147,456
#      BatchNorm2d-186         [-1, 128, 64, 128]             256
#             ReLU-187         [-1, 128, 64, 128]               0
#         BGALayer-188         [-1, 128, 64, 128]               0
#           Conv2d-189        [-1, 128, 128, 256]          18,432
#      BatchNorm2d-190        [-1, 128, 128, 256]             256
#             ReLU-191        [-1, 128, 128, 256]               0
#        ConvBlock-192        [-1, 128, 128, 256]               0
#          Dropout-193        [-1, 128, 128, 256]               0
#           Conv2d-194         [-1, 19, 128, 256]           2,451
#          SegHead-195        [-1, 19, 512, 1024]               0
#           Conv2d-196         [-1, 128, 64, 128]          36,864
#      BatchNorm2d-197         [-1, 128, 64, 128]             256
#             ReLU-198         [-1, 128, 64, 128]               0
#        ConvBlock-199         [-1, 128, 64, 128]               0
#          Dropout-200         [-1, 128, 64, 128]               0
#           Conv2d-201          [-1, 19, 64, 128]           2,451
#          SegHead-202        [-1, 19, 512, 1024]               0
#           Conv2d-203          [-1, 128, 32, 64]          73,728
#      BatchNorm2d-204          [-1, 128, 32, 64]             256
#             ReLU-205          [-1, 128, 32, 64]               0
#        ConvBlock-206          [-1, 128, 32, 64]               0
#          Dropout-207          [-1, 128, 32, 64]               0
#           Conv2d-208           [-1, 19, 32, 64]           2,451
#          SegHead-209        [-1, 19, 512, 1024]               0
#           Conv2d-210          [-1, 128, 16, 32]         147,456
#      BatchNorm2d-211          [-1, 128, 16, 32]             256
#             ReLU-212          [-1, 128, 16, 32]               0
#        ConvBlock-213          [-1, 128, 16, 32]               0
#          Dropout-214          [-1, 128, 16, 32]               0
#           Conv2d-215           [-1, 19, 16, 32]           2,451
#          SegHead-216        [-1, 19, 512, 1024]               0
#           Conv2d-217        [-1, 1024, 64, 128]       1,179,648
#      BatchNorm2d-218        [-1, 1024, 64, 128]           2,048
#             ReLU-219        [-1, 1024, 64, 128]               0
#        ConvBlock-220        [-1, 1024, 64, 128]               0
#          Dropout-221        [-1, 1024, 64, 128]               0
#           Conv2d-222          [-1, 19, 64, 128]          19,475
#          SegHead-223        [-1, 19, 512, 1024]               0
# ================================================================
# Total params: 3,645,935
# Trainable params: 3,645,935
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 6.00
# Forward/backward pass size (MB): 2176.00
# Params size (MB): 13.91
# Estimated Total Size (MB): 2195.91
# ----------------------------------------------------------------

# %% [markdown]
# # Set optimizer, loss function

# %%
lr = 0.05
es_save_path = './model/es_checkpoint.pt'
cp_save_path = './model/cp_checkpoint.pt'
loss_func = OhemCELoss(thresh=0.7, ignore_lb=255).to(device)
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4)
lr_scheduler = PolynomialLRDecay(optimizer, max_decay_steps=1000)
metric = Metrics(n_classes=num_classes, dim=1)
checkpoint = CheckPoint(verbose=True, path=cp_save_path)
early_stopping = EarlyStopping(patience=300, verbose=True, path=es_save_path)

# %%
def valid_step(model, validation_data):
    model.eval()
    with torch.no_grad():
        vbatch_loss, vbatch_miou = 0, 0
        for vbatch, (val_images, val_labels) in enumerate(validation_data):
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            
            val_outputs, v_s2, v_s3, v_s4, v_s5 = model(val_images)
            
            val_miou = metric.mean_iou(val_outputs, val_labels)
            vbatch_miou += val_miou.item()
            
            p_val_loss = loss_func(val_outputs, val_labels.squeeze())
            a_val_loss1 = loss_func(v_s2, val_labels.squeeze())
            a_val_loss2 = loss_func(v_s3, val_labels.squeeze())
            a_val_loss3 = loss_func(v_s4, val_labels.squeeze())
            a_val_loss4 = loss_func(v_s5, val_labels.squeeze())
            val_loss = p_val_loss + (a_val_loss1+a_val_loss2+a_val_loss3+a_val_loss4)
            vbatch_loss += val_loss.item()
            
            del val_images; del val_labels; del val_outputs
            del v_s2; del v_s3; del v_s4; del v_s5
            torch.cuda.empty_cache()
            
    return vbatch_loss/(vbatch+1), vbatch_miou/(vbatch+1)

def train_on_batch(model, train_data):
    batch_loss, batch_miou = 0, 0
    for batch, (train_images, train_labels) in enumerate(train_data):
        model.train()

        train_images = train_images.to(device)
        train_labels = train_labels.to(device)

        optimizer.zero_grad()

        train_outputs, s2, s3, s4, s5 = model(train_images)

        miou = metric.mean_iou(train_outputs, train_labels)
        batch_miou += miou.item()

        p_loss = loss_func(train_outputs, train_labels.squeeze())
        a_loss1 = loss_func(s2, train_labels.squeeze())
        a_loss2 = loss_func(s3, train_labels.squeeze())
        a_loss3 = loss_func(s4, train_labels.squeeze())
        a_loss4 = loss_func(s5, train_labels.squeeze())
        loss = p_loss + (a_loss1+a_loss2+a_loss3+a_loss4)
        batch_loss += loss.item()

        loss.backward()
        optimizer.step()

        del train_images; del train_labels; del train_outputs
        del s2; del s3; del s4; del s5
        torch.cuda.empty_cache()

    return batch_loss/(batch+1), batch_miou/(batch+1)

def train_step(model,
               train_data,
               validation_data,
               epochs,
               learning_rate_scheduler=False,
               check_point=False,
               early_stop=False,
               last_epoch_save_path='./model/last_checkpoint.pt'):
    
    loss_list, miou_list = [], []
    val_loss_list, val_miou_list = [], []
    
    print('Start Model Training...!')
    start_training = time.time()
    for epoch in tqdm(range(epochs)):
        init_time = time.time()
        
        train_loss, train_miou = train_on_batch(model, train_data)
        loss_list.append(train_loss)
        miou_list.append(train_miou)
            
        val_loss, val_miou = valid_step(model, validation_data)
        val_loss_list.append(val_loss)
        val_miou_list.append(val_miou)
        
        end_time = time.time()
        
        print(f'\n[Epoch {epoch+1}/{epochs}]'
              f'  [time: {end_time-init_time:.3f}s]'
              f'  [lr = {optimizer.param_groups[0]["lr"]}]')
        print(f'[train loss: {train_loss:.3f}]'
              f'  [train miou: {train_miou:.3f}]'
              f'  [valid loss: {val_loss:.3f}]'
              f'  [valid miou: {val_miou:.3f}]')
        
        if learning_rate_scheduler:
            lr_scheduler.step()
            
        if check_point:
            checkpoint(val_loss, model)
            
        if early_stop:
            assert check_point==False, 'Choose between Early Stopping and Check Point'
            early_stopping(val_loss, model)
            if early_stopping.early_stop:
                print('\n##########################\n'
                      '##### Early Stopping #####\n'
                      '##########################')
                break
                
    if early_stop==False and check_point==False:
        torch.save(model.state_dict(), last_epoch_save_path)
        print('Saving model of last epoch.')
        
    end_training = time.time()
    print(f'\nTotal time for training is {end_training-start_training:.3f}s')
    
    return {
        'model': model, 
        'loss': loss_list, 
        'miou': miou_list, 
        'val_loss': val_loss_list, 
        'val_miou': val_miou_list
        }

# %%
EPOCH = 1000

history = train_step(
    model,
    train_data=train_loader,
    validation_data=valid_loader,
    epochs=EPOCH,
    learning_rate_scheduler=True,
    check_point=True,
    early_stop=False,
)
# Out:
# Start Model Training...!
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [Epoch 1/1000]  [time: 771.766s]  [lr = 0.049955006749624734]
# [train loss: 11.064]  [train miou: 0.037]  [valid loss: 7.820]  [valid miou: 0.078]
# Validation loss decreased (inf --> 7.820).  Saving model ...
#
# [Epoch 2/1000]  [time: 757.138s]  [lr = 0.049910008995194384]
# [train loss: 8.531]  [train miou: 0.080]  [valid loss: 8.160]  [valid miou: 0.098]
#
# [Epoch 3/1000]  [time: 756.575s]  [lr = 0.049865006731744314]
# [train loss: 8.170]  [train miou: 0.114]  [valid loss: 8.015]  [valid miou: 0.124]
#
# [Epoch 4/1000]  [time: 755.098s]  [lr = 0.049819999954299435]
# [train loss: 7.919]  [train miou: 0.138]  [valid loss: 8.861]  [valid miou: 0.122]
#
# [Epoch 5/1000]  [time: 756.390s]  [lr = 0.049774988657874136]
# [train loss: 7.817]  [train miou: 0.154]  [valid loss: 7.032]  [valid miou: 0.137]
# Validation loss decreased (7.820 --> 7.032).  Saving model ...
#
# [Epoch 6/1000]  [time: 756.157s]  [lr = 0.04972997283747233]
# [train loss: 7.654]  [train miou: 0.165]  [valid loss: 7.527]  [valid miou: 0.177]
#
# [Epoch 7/1000]  [time: 757.105s]  [lr = 0.04968495248808734]
# [train loss: 7.538]  [train miou: 0.178]  [valid loss: 6.969]  [valid miou: 0.169]
# Validation loss decreased (7.032 --> 6.969).  Saving model ...
#
# [Epoch 8/1000]  [time: 760.768s]  [lr = 0.049639927604701914]
# [train loss: 7.391]  [train miou: 0.190]  [valid loss: 7.534]  [valid miou: 0.176]
#
# [Epoch 9/1000]  [time: 757.537s]  [lr = 0.04959489818228817]
# [train loss: 7.375]  [train miou: 0.200]  [valid loss: 6.520]  [valid miou: 0.199]
# Validation loss decreased (6.969 --> 6.520).  Saving model ...
#
# [Epoch 10/1000]  [time: 757.333s]  [lr = 0.049549864215807586]
# [train loss: 7.302]  [train miou: 0.207]  [valid loss: 7.791]  [valid miou: 0.194]
#
# [Epoch 11/1000]  [time: 756.189s]  [lr = 0.04950482570021094]
# [train loss: 7.224]  [train miou: 0.220]  [valid loss: 7.992]  [valid miou: 0.195]
#
# [Epoch 12/1000]  [time: 756.367s]  [lr = 0.04945978263043828]
# [train loss: 7.208]  [train miou: 0.225]  [valid loss: 6.662]  [valid miou: 0.211]
#
# [Epoch 13/1000]  [time: 756.912s]  [lr = 0.04941473500141892]
# [train loss: 7.175]  [train miou: 0.233]  [valid loss: 8.343]  [valid miou: 0.199]
#
# [Epoch 14/1000]  [time: 757.764s]  [lr = 0.049369682808071365]
# [train loss: 7.067]  [train miou: 0.242]  [valid loss: 8.450]  [valid miou: 0.183]
#
# [Epoch 15/1000]  [time: 756.955s]  [lr = 0.04932462604530331]
# [train loss: 7.075]  [train miou: 0.244]  [valid loss: 7.633]  [valid miou: 0.228]
#
# [Epoch 16/1000]  [time: 758.264s]  [lr = 0.0492795647080116]
# [train loss: 7.055]  [train miou: 0.250]  [valid loss: 7.406]  [valid miou: 0.221]
#
# [Epoch 17/1000]  [time: 756.930s]  [lr = 0.04923449879108215]
# [train loss: 7.023]  [train miou: 0.252]  [valid loss: 7.226]  [valid miou: 0.231]
#
# [Epoch 18/1000]  [time: 756.707s]  [lr = 0.049189428289390005]
# [train loss: 6.952]  [train miou: 0.261]  [valid loss: 8.111]  [valid miou: 0.234]
#
# [Epoch 19/1000]  [time: 759.004s]  [lr = 0.049144353197799195]
# [train loss: 6.978]  [train miou: 0.268]  [valid loss: 7.385]  [valid miou: 0.212]
#
# [Epoch 20/1000]  [time: 772.192s]  [lr = 0.0490992735111628]
# [train loss: 6.975]  [train miou: 0.267]  [valid loss: 7.011]  [valid miou: 0.238]
#
# [Epoch 21/1000]  [time: 774.573s]  [lr = 0.049054189224322836]
# [train loss: 6.854]  [train miou: 0.280]  [valid loss: 7.758]  [valid miou: 0.270]
#
# [Epoch 22/1000]  [time: 782.314s]  [lr = 0.04900910033211028]
# [train loss: 6.928]  [train miou: 0.288]  [valid loss: 8.012]  [valid miou: 0.255]
#
# [Epoch 23/1000]  [time: 769.205s]  [lr = 0.04896400682934499]
# [train loss: 6.868]  [train miou: 0.286]  [valid loss: 6.284]  [valid miou: 0.280]
# Validation loss decreased (6.520 --> 6.284).  Saving model ...
#
# [Epoch 24/1000]  [time: 769.065s]  [lr = 0.0489189087108357]
# [train loss: 6.788]  [train miou: 0.291]  [valid loss: 7.006]  [valid miou: 0.242]
#
# [Epoch 25/1000]  [time: 762.759s]  [lr = 0.048873805971379976]
# [train loss: 6.853]  [train miou: 0.291]  [valid loss: 7.833]  [valid miou: 0.225]
#
# [Epoch 26/1000]  [time: 758.807s]  [lr = 0.04882869860576417]
# [train loss: 6.863]  [train miou: 0.299]  [valid loss: 7.637]  [valid miou: 0.271]
#
# [Epoch 27/1000]  [time: 758.923s]  [lr = 0.0487835866087634]
# [train loss: 6.784]  [train miou: 0.302]  [valid loss: 7.921]  [valid miou: 0.261]
#
# [Epoch 28/1000]  [time: 763.187s]  [lr = 0.04873846997514149]
# [train loss: 6.892]  [train miou: 0.304]  [valid loss: 7.469]  [valid miou: 0.280]
#
# [Epoch 29/1000]  [time: 762.026s]  [lr = 0.04869334869965097]
# [train loss: 6.752]  [train miou: 0.314]  [valid loss: 6.777]  [valid miou: 0.304]
#
# [Epoch 30/1000]  [time: 759.153s]  [lr = 0.048648222777033026]
# [train loss: 6.838]  [train miou: 0.306]  [valid loss: 7.049]  [valid miou: 0.298]
#
# [Epoch 31/1000]  [time: 760.088s]  [lr = 0.04860309220201743]
# [train loss: 6.776]  [train miou: 0.312]  [valid loss: 7.892]  [valid miou: 0.247]
#
# [Epoch 32/1000]  [time: 765.034s]  [lr = 0.04855795696932255]
# [train loss: 6.850]  [train miou: 0.312]  [valid loss: 7.440]  [valid miou: 0.286]
#
# [Epoch 33/1000]  [time: 768.201s]  [lr = 0.048512817073655304]
# [train loss: 6.763]  [train miou: 0.317]  [valid loss: 6.826]  [valid miou: 0.275]
#
# [Epoch 34/1000]  [time: 768.282s]  [lr = 0.048467672509711096]
# [train loss: 6.764]  [train miou: 0.315]  [valid loss: 6.934]  [valid miou: 0.287]
#
# [Epoch 35/1000]  [time: 767.597s]  [lr = 0.0484225232721738]
# [train loss: 6.739]  [train miou: 0.325]  [valid loss: 7.547]  [valid miou: 0.274]
#
# [Epoch 36/1000]  [time: 767.779s]  [lr = 0.04837736935571574]
# [train loss: 6.770]  [train miou: 0.315]  [valid loss: 6.646]  [valid miou: 0.295]
#
# [Epoch 37/1000]  [time: 767.576s]  [lr = 0.04833221075499761]
# [train loss: 6.766]  [train miou: 0.321]  [valid loss: 6.627]  [valid miou: 0.308]
#
# [Epoch 38/1000]  [time: 767.316s]  [lr = 0.04828704746466847]
# [train loss: 6.687]  [train miou: 0.324]  [valid loss: 7.176]  [valid miou: 0.289]
#
# [Epoch 39/1000]  [time: 768.367s]  [lr = 0.0482418794793657]
# [train loss: 6.732]  [train miou: 0.330]  [valid loss: 7.031]  [valid miou: 0.269]
#
# [Epoch 40/1000]  [time: 768.730s]  [lr = 0.04819670679371497]
# [train loss: 6.734]  [train miou: 0.321]  [valid loss: 7.515]  [valid miou: 0.304]
#
# [Epoch 41/1000]  [time: 766.214s]  [lr = 0.04815152940233016]
# [train loss: 6.716]  [train miou: 0.331]  [valid loss: 6.705]  [valid miou: 0.297]
#
# [Epoch 42/1000]  [time: 766.009s]  [lr = 0.04810634729981338]
# [train loss: 6.717]  [train miou: 0.336]  [valid loss: 7.091]  [valid miou: 0.270]
#
# [Epoch 43/1000]  [time: 767.482s]  [lr = 0.048061160480754934]
# [train loss: 6.624]  [train miou: 0.341]  [valid loss: 7.146]  [valid miou: 0.305]
#
# [Epoch 44/1000]  [time: 769.004s]  [lr = 0.04801596893973319]
# [train loss: 6.708]  [train miou: 0.335]  [valid loss: 7.090]  [valid miou: 0.288]
#
# [Epoch 45/1000]  [time: 766.574s]  [lr = 0.047970772671314665]
# [train loss: 6.655]  [train miou: 0.339]  [valid loss: 7.832]  [valid miou: 0.237]
#
# [Epoch 46/1000]  [time: 768.174s]  [lr = 0.04792557167005389]
# [train loss: 6.729]  [train miou: 0.336]  [valid loss: 6.623]  [valid miou: 0.301]
#
# [Epoch 47/1000]  [time: 766.303s]  [lr = 0.04788036593049341]
# [train loss: 6.726]  [train miou: 0.342]  [valid loss: 6.607]  [valid miou: 0.319]
#
# [Epoch 48/1000]  [time: 766.816s]  [lr = 0.047835155447163775]
# [train loss: 6.604]  [train miou: 0.348]  [valid loss: 6.254]  [valid miou: 0.322]
# Validation loss decreased (6.284 --> 6.254).  Saving model ...
#
# [Epoch 49/1000]  [time: 767.726s]  [lr = 0.047789940214583444]
# [train loss: 6.602]  [train miou: 0.344]  [valid loss: 6.780]  [valid miou: 0.296]
#
# [Epoch 50/1000]  [time: 768.159s]  [lr = 0.04774472022725877]
# [train loss: 6.647]  [train miou: 0.347]  [valid loss: 6.301]  [valid miou: 0.288]
#
# [Epoch 51/1000]  [time: 765.989s]  [lr = 0.04769949547968398]
# [train loss: 6.655]  [train miou: 0.349]  [valid loss: 6.963]  [valid miou: 0.331]
#
# [Epoch 52/1000]  [time: 767.322s]  [lr = 0.0476542659663411]
# [train loss: 6.654]  [train miou: 0.349]  [valid loss: 6.258]  [valid miou: 0.299]
#
# [Epoch 53/1000]  [time: 764.735s]  [lr = 0.04760903168169992]
# [train loss: 6.573]  [train miou: 0.354]  [valid loss: 7.965]  [valid miou: 0.298]
#
# [Epoch 54/1000]  [time: 766.588s]  [lr = 0.047563792620218]
# [train loss: 6.585]  [train miou: 0.359]  [valid loss: 7.307]  [valid miou: 0.283]
# [Epoch 55/1000]  [time: 769.123s]  [lr = 0.047518548776340576]
# [train loss: 6.650]  [train miou: 0.353]  [valid loss: 7.259]  [valid miou: 0.282]
#
# [Epoch 56/1000]  [time: 766.020s]  [lr = 0.047473300144500546]
# [train loss: 6.579]  [train miou: 0.353]  [valid loss: 6.678]  [valid miou: 0.331]
#
# [Epoch 57/1000]  [time: 767.205s]  [lr = 0.047428046719118405]
# [train loss: 6.603]  [train miou: 0.360]  [valid loss: 6.600]  [valid miou: 0.347]
#
# [Epoch 58/1000]  [time: 767.920s]  [lr = 0.04738278849460224]
# [train loss: 6.572]  [train miou: 0.358]  [valid loss: 6.890]  [valid miou: 0.315]
#
# [Epoch 59/1000]  [time: 769.967s]  [lr = 0.04733752546534768]
# [train loss: 6.535]  [train miou: 0.358]  [valid loss: 7.340]  [valid miou: 0.287]
#
# [Epoch 60/1000]  [time: 765.900s]  [lr = 0.04729225762573782]
# [train loss: 6.556]  [train miou: 0.364]  [valid loss: 7.173]  [valid miou: 0.328]
#
# [Epoch 61/1000]  [time: 766.019s]  [lr = 0.04724698497014323]
# [train loss: 6.598]  [train miou: 0.369]  [valid loss: 7.441]  [valid miou: 0.320]
#
# [Epoch 62/1000]  [time: 768.532s]  [lr = 0.04720170749292186]
# [train loss: 6.595]  [train miou: 0.366]  [valid loss: 6.885]  [valid miou: 0.306]
#
# [Epoch 63/1000]  [time: 765.433s]  [lr = 0.04715642518841907]
# [train loss: 6.610]  [train miou: 0.362]  [valid loss: 6.134]  [valid miou: 0.305]
# Validation loss decreased (6.254 --> 6.134).  Saving model ...
#
# [Epoch 64/1000]  [time: 766.882s]  [lr = 0.0471111380509675]
# [train loss: 6.566]  [train miou: 0.366]  [valid loss: 7.054]  [valid miou: 0.329]
#
# [Epoch 65/1000]  [time: 765.016s]  [lr = 0.04706584607488712]
# [train loss: 6.545]  [train miou: 0.366]  [valid loss: 6.805]  [valid miou: 0.337]
#
# [Epoch 66/1000]  [time: 764.717s]  [lr = 0.047020549254485094]
# [train loss: 6.526]  [train miou: 0.369]  [valid loss: 6.854]  [valid miou: 0.328]
#
# [Epoch 67/1000]  [time: 766.173s]  [lr = 0.046975247584055836]
# [train loss: 6.573]  [train miou: 0.368]  [valid loss: 6.216]  [valid miou: 0.335]
#
# [Epoch 68/1000]  [time: 765.007s]  [lr = 0.04692994105788087]
# [train loss: 6.512]  [train miou: 0.371]  [valid loss: 7.177]  [valid miou: 0.334]
#
# [Epoch 69/1000]  [time: 765.941s]  [lr = 0.046884629670228876]
# [train loss: 6.603]  [train miou: 0.369]  [valid loss: 6.603]  [valid miou: 0.337]
#
# [Epoch 70/1000]  [time: 767.688s]  [lr = 0.04683931341535556]
# [train loss: 6.501]  [train miou: 0.372]  [valid loss: 7.011]  [valid miou: 0.355]
#
# [Epoch 71/1000]  [time: 763.582s]  [lr = 0.046793992287503715]
# [train loss: 6.513]  [train miou: 0.384]  [valid loss: 6.093]  [valid miou: 0.338]
# Validation loss decreased (6.134 --> 6.093).  Saving model ...
#
# [Epoch 72/1000]  [time: 766.731s]  [lr = 0.04674866628090306]
# [train loss: 6.551]  [train miou: 0.376]  [valid loss: 6.139]  [valid miou: 0.357]
#
# [Epoch 73/1000]  [time: 766.772s]  [lr = 0.046703335389770284]
# [train loss: 6.537]  [train miou: 0.376]  [valid loss: 6.301]  [valid miou: 0.333]
#
# [Epoch 74/1000]  [time: 766.361s]  [lr = 0.04665799960830898]
# [train loss: 6.520]  [train miou: 0.382]  [valid loss: 7.181]  [valid miou: 0.349]
#
# [Epoch 75/1000]  [time: 766.574s]  [lr = 0.04661265893070959]
# [train loss: 6.546]  [train miou: 0.381]  [valid loss: 6.646]  [valid miou: 0.336]
#
# [Epoch 76/1000]  [time: 767.402s]  [lr = 0.046567313351149345]
# [train loss: 6.558]  [train miou: 0.376]  [valid loss: 7.706]  [valid miou: 0.312]
#
# [Epoch 77/1000]  [time: 769.944s]  [lr = 0.046521962863792274]
# [train loss: 6.537]  [train miou: 0.388]  [valid loss: 6.921]  [valid miou: 0.378]
#
# [Epoch 78/1000]  [time: 771.146s]  [lr = 0.046476607462789116]
# [train loss: 6.548]  [train miou: 0.380]  [valid loss: 7.407]  [valid miou: 0.322]
#
# [Epoch 79/1000]  [time: 771.179s]  [lr = 0.04643124714227726]
# [train loss: 6.502]  [train miou: 0.384]  [valid loss: 6.944]  [valid miou: 0.364]
#
# [Epoch 80/1000]  [time: 771.901s]  [lr = 0.04638588189638078]
# [train loss: 6.523]  [train miou: 0.387]  [valid loss: 6.244]  [valid miou: 0.337]
#
# [Epoch 81/1000]  [time: 769.358s]  [lr = 0.04634051171921029]
# [train loss: 6.538]  [train miou: 0.379]  [valid loss: 6.949]  [valid miou: 0.338]
#
# [Epoch 82/1000]  [time: 770.458s]  [lr = 0.04629513660486296]
# [train loss: 6.454]  [train miou: 0.393]  [valid loss: 7.218]  [valid miou: 0.352]
#
# [Epoch 83/1000]  [time: 772.510s]  [lr = 0.046249756547422465]
# [train loss: 6.536]  [train miou: 0.390]  [valid loss: 6.681]  [valid miou: 0.360]
#
# [Epoch 84/1000]  [time: 769.377s]  [lr = 0.046204371540958925]
# [train loss: 6.590]  [train miou: 0.386]  [valid loss: 6.518]  [valid miou: 0.331]
#
# [Epoch 85/1000]  [time: 771.582s]  [lr = 0.04615898157952885]
# [train loss: 6.460]  [train miou: 0.399]  [valid loss: 6.614]  [valid miou: 0.370]
#
# [Epoch 86/1000]  [time: 769.764s]  [lr = 0.04611358665717514]
# [train loss: 6.497]  [train miou: 0.395]  [valid loss: 6.860]  [valid miou: 0.367]
#
# [Epoch 87/1000]  [time: 768.355s]  [lr = 0.04606818676792698]
# [train loss: 6.457]  [train miou: 0.402]  [valid loss: 6.242]  [valid miou: 0.354]
#
# [Epoch 88/1000]  [time: 769.766s]  [lr = 0.04602278190579983]
# [train loss: 6.437]  [train miou: 0.401]  [valid loss: 6.359]  [valid miou: 0.344]
#
# [Epoch 89/1000]  [time: 771.969s]  [lr = 0.04597737206479537]
# [train loss: 6.478]  [train miou: 0.396]  [valid loss: 7.054]  [valid miou: 0.350]
#
# [Epoch 90/1000]  [time: 760.983s]  [lr = 0.04593195723890146]
# [train loss: 6.437]  [train miou: 0.400]  [valid loss: 6.982]  [valid miou: 0.360]
#
# [Epoch 91/1000]  [time: 751.907s]  [lr = 0.04588653742209205]
# [train loss: 6.498]  [train miou: 0.399]  [valid loss: 8.561]  [valid miou: 0.269]
#
# [Epoch 92/1000]  [time: 757.130s]  [lr = 0.04584111260832721]
# [train loss: 6.533]  [train miou: 0.394]  [valid loss: 6.881]  [valid miou: 0.397]
#
# [Epoch 93/1000]  [time: 758.573s]  [lr = 0.04579568279155303]
# [train loss: 6.473]  [train miou: 0.402]  [valid loss: 6.759]  [valid miou: 0.332]
#
# [Epoch 94/1000]  [time: 753.157s]  [lr = 0.04575024796570157]
# [train loss: 6.520]  [train miou: 0.392]  [valid loss: 6.464]  [valid miou: 0.372]
#
# [Epoch 95/1000]  [time: 755.258s]  [lr = 0.045704808124690834]
# [train loss: 6.501]  [train miou: 0.398]  [valid loss: 6.642]  [valid miou: 0.387]
#
# [Epoch 96/1000]  [time: 753.137s]  [lr = 0.0456593632624247]
# [train loss: 6.397]  [train miou: 0.403]  [valid loss: 6.793]  [valid miou: 0.373]
#
# [Epoch 97/1000]  [time: 751.128s]  [lr = 0.0456139133727929]
# [train loss: 6.491]  [train miou: 0.401]  [valid loss: 7.138]  [valid miou: 0.355]
#
# [Epoch 98/1000]  [time: 752.201s]  [lr = 0.045568458449670945]
# [train loss: 6.476]  [train miou: 0.402]  [valid loss: 7.397]  [valid miou: 0.364]
#
# [Epoch 99/1000]  [time: 750.218s]  [lr = 0.04552299848692009]
# [train loss: 6.444]  [train miou: 0.405]  [valid loss: 6.891]  [valid miou: 0.321]
#
# [Epoch 100/1000]  [time: 750.575s]  [lr = 0.04547753347838728]
# [train loss: 6.478]  [train miou: 0.399]  [valid loss: 7.085]  [valid miou: 0.354]
#
# [Epoch 101/1000]  [time: 751.715s]  [lr = 0.045432063417905115]
# [train loss: 6.473]  [train miou: 0.412]  [valid loss: 6.844]  [valid miou: 0.343]
#
# [Epoch 102/1000]  [time: 751.618s]  [lr = 0.04538658829929176]
# [train loss: 6.386]  [train miou: 0.411]  [valid loss: 7.449]  [valid miou: 0.318]
#
# [Epoch 103/1000]  [time: 749.467s]  [lr = 0.04534110811635094]
# [train loss: 6.517]  [train miou: 0.399]  [valid loss: 6.967]  [valid miou: 0.375]
#
# [Epoch 104/1000]  [time: 750.421s]  [lr = 0.04529562286287188]
# [train loss: 6.488]  [train miou: 0.402]  [valid loss: 6.439]  [valid miou: 0.344]
#
# [Epoch 105/1000]  [time: 755.388s]  [lr = 0.04525013253262924]
# [train loss: 6.562]  [train miou: 0.400]  [valid loss: 6.273]  [valid miou: 0.328]
#
# [Epoch 106/1000]  [time: 757.138s]  [lr = 0.04520463711938305]
# [train loss: 6.506]  [train miou: 0.407]  [valid loss: 6.866]  [valid miou: 0.387]
#
# [Epoch 107/1000]  [time: 757.600s]  [lr = 0.04515913661687873]
# [train loss: 6.425]  [train miou: 0.407]  [valid loss: 7.342]  [valid miou: 0.301]
#
# [Epoch 108/1000]  [time: 750.789s]  [lr = 0.04511363101884695]
# [train loss: 6.384]  [train miou: 0.414]  [valid loss: 7.320]  [valid miou: 0.354]
#
# [Epoch 109/1000]  [time: 761.138s]  [lr = 0.04506812031900363]
# [train loss: 6.527]  [train miou: 0.408]  [valid loss: 7.471]  [valid miou: 0.341]
#
# [Epoch 110/1000]  [time: 755.994s]  [lr = 0.045022604511049884]
# [train loss: 6.432]  [train miou: 0.418]  [valid loss: 6.398]  [valid miou: 0.368]
# [Epoch 111/1000]  [time: 756.147s]  [lr = 0.044977083588671966]
# [train loss: 6.515]  [train miou: 0.402]  [valid loss: 7.403]  [valid miou: 0.360]
#
# [Epoch 112/1000]  [time: 756.958s]  [lr = 0.0449315575455412]
# [train loss: 6.471]  [train miou: 0.410]  [valid loss: 6.503]  [valid miou: 0.394]
#
# [Epoch 113/1000]  [time: 756.710s]  [lr = 0.04488602637531396]
# [train loss: 6.479]  [train miou: 0.411]  [valid loss: 6.835]  [valid miou: 0.370]
#
# [Epoch 114/1000]  [time: 754.820s]  [lr = 0.044840490071631586]
# [train loss: 6.478]  [train miou: 0.419]  [valid loss: 6.882]  [valid miou: 0.352]
#
# [Epoch 115/1000]  [time: 758.727s]  [lr = 0.04479494862812035]
# [train loss: 6.460]  [train miou: 0.418]  [valid loss: 6.655]  [valid miou: 0.380]
#
# [Epoch 116/1000]  [time: 756.616s]  [lr = 0.044749402038391395]
# [train loss: 6.517]  [train miou: 0.407]  [valid loss: 6.713]  [valid miou: 0.339]
#
# [Epoch 117/1000]  [time: 763.527s]  [lr = 0.04470385029604071]
# [train loss: 6.438]  [train miou: 0.417]  [valid loss: 7.115]  [valid miou: 0.375]
#
# [Epoch 118/1000]  [time: 750.793s]  [lr = 0.04465829339464902]
# [train loss: 6.471]  [train miou: 0.420]  [valid loss: 6.609]  [valid miou: 0.373]
#
# [Epoch 119/1000]  [time: 759.159s]  [lr = 0.04461273132778178]
# [train loss: 6.461]  [train miou: 0.410]  [valid loss: 7.114]  [valid miou: 0.390]
#
# [Epoch 120/1000]  [time: 765.541s]  [lr = 0.04456716408898911]
# [train loss: 6.407]  [train miou: 0.422]  [valid loss: 6.789]  [valid miou: 0.365]
#
# [Epoch 121/1000]  [time: 754.348s]  [lr = 0.044521591671805735]
# [train loss: 6.354]  [train miou: 0.430]  [valid loss: 7.080]  [valid miou: 0.368]
#
# [Epoch 122/1000]  [time: 754.604s]  [lr = 0.04447601406975092]
# [train loss: 6.600]  [train miou: 0.402]  [valid loss: 6.447]  [valid miou: 0.367]
#
# [Epoch 123/1000]  [time: 754.199s]  [lr = 0.044430431276328446]
# [train loss: 6.447]  [train miou: 0.413]  [valid loss: 7.267]  [valid miou: 0.366]
#
# [Epoch 124/1000]  [time: 752.737s]  [lr = 0.04438484328502654]
# [train loss: 6.440]  [train miou: 0.419]  [valid loss: 5.971]  [valid miou: 0.335]
# Validation loss decreased (6.093 --> 5.971).  Saving model ...
#
# [Epoch 125/1000]  [time: 752.343s]  [lr = 0.04433925008931779]
# [train loss: 6.450]  [train miou: 0.418]  [valid loss: 7.372]  [valid miou: 0.349]
#
# [Epoch 126/1000]  [time: 754.559s]  [lr = 0.04429365168265916]
# [train loss: 6.470]  [train miou: 0.412]  [valid loss: 6.514]  [valid miou: 0.369]
#
# [Epoch 127/1000]  [time: 753.569s]  [lr = 0.044248048058491855]
# [train loss: 6.454]  [train miou: 0.418]  [valid loss: 5.836]  [valid miou: 0.384]
# Validation loss decreased (5.971 --> 5.836).  Saving model ...
#
# [Epoch 128/1000]  [time: 753.726s]  [lr = 0.044202439210241314]
# [train loss: 6.403]  [train miou: 0.427]  [valid loss: 6.880]  [valid miou: 0.368]
#
# [Epoch 129/1000]  [time: 757.970s]  [lr = 0.04415682513131714]
# [train loss: 6.446]  [train miou: 0.424]  [valid loss: 6.690]  [valid miou: 0.365]
#
# [Epoch 130/1000]  [time: 755.958s]  [lr = 0.04411120581511306]
# [train loss: 6.528]  [train miou: 0.413]  [valid loss: 6.361]  [valid miou: 0.355]
#
# [Epoch 131/1000]  [time: 771.205s]  [lr = 0.044065581255006835]
# [train loss: 6.406]  [train miou: 0.422]  [valid loss: 7.208]  [valid miou: 0.364]
#
# [Epoch 132/1000]  [time: 771.517s]  [lr = 0.04401995144436023]
# [train loss: 6.434]  [train miou: 0.429]  [valid loss: 6.890]  [valid miou: 0.386]
#
# [Epoch 133/1000]  [time: 758.763s]  [lr = 0.04397431637651895]
# [train loss: 6.389]  [train miou: 0.422]  [valid loss: 6.876]  [valid miou: 0.367]
#
# [Epoch 134/1000]  [time: 757.216s]  [lr = 0.04392867604481257]
# [train loss: 6.412]  [train miou: 0.425]  [valid loss: 6.064]  [valid miou: 0.393]
#
# [Epoch 135/1000]  [time: 758.161s]  [lr = 0.04388303044255452]
# [train loss: 6.399]  [train miou: 0.429]  [valid loss: 6.091]  [valid miou: 0.354]
#
# [Epoch 136/1000]  [time: 768.742s]  [lr = 0.04383737956304195]
# [train loss: 6.420]  [train miou: 0.423]  [valid loss: 6.856]  [valid miou: 0.387]
#
# [Epoch 137/1000]  [time: 770.754s]  [lr = 0.04379172339955575]
# [train loss: 6.397]  [train miou: 0.424]  [valid loss: 6.767]  [valid miou: 0.370]
#
# [Epoch 138/1000]  [time: 765.763s]  [lr = 0.04374606194536045]
# [train loss: 6.450]  [train miou: 0.428]  [valid loss: 6.337]  [valid miou: 0.366]
#
# [Epoch 139/1000]  [time: 771.799s]  [lr = 0.04370039519370418]
# [train loss: 6.340]  [train miou: 0.433]  [valid loss: 7.597]  [valid miou: 0.391]
#
# [Epoch 140/1000]  [time: 770.724s]  [lr = 0.04365472313781858]
# [train loss: 6.481]  [train miou: 0.419]  [valid loss: 6.875]  [valid miou: 0.355]
#
# [Epoch 141/1000]  [time: 767.403s]  [lr = 0.04360904577091878]
# [train loss: 6.361]  [train miou: 0.426]  [valid loss: 6.626]  [valid miou: 0.393]
#
# [Epoch 142/1000]  [time: 766.146s]  [lr = 0.04356336308620331]
# [train loss: 6.414]  [train miou: 0.425]  [valid loss: 6.468]  [valid miou: 0.364]
#
# [Epoch 143/1000]  [time: 755.510s]  [lr = 0.04351767507685406]
# [train loss: 6.451]  [train miou: 0.421]  [valid loss: 6.491]  [valid miou: 0.407]
#
# [Epoch 144/1000]  [time: 757.371s]  [lr = 0.043471981736036204]
# [train loss: 6.414]  [train miou: 0.428]  [valid loss: 6.635]  [valid miou: 0.400]
#
# [Epoch 145/1000]  [time: 754.578s]  [lr = 0.043426283056898156]
# [train loss: 6.430]  [train miou: 0.427]  [valid loss: 7.026]  [valid miou: 0.364]
#
# [Epoch 146/1000]  [time: 757.401s]  [lr = 0.043380579032571503]
# [train loss: 6.421]  [train miou: 0.427]  [valid loss: 6.207]  [valid miou: 0.401]
#
# [Epoch 147/1000]  [time: 755.927s]  [lr = 0.04333486965617093]
# [train loss: 6.390]  [train miou: 0.434]  [valid loss: 6.577]  [valid miou: 0.400]
#
# [Epoch 148/1000]  [time: 757.014s]  [lr = 0.043289154920794166]
# [train loss: 6.372]  [train miou: 0.434]  [valid loss: 6.698]  [valid miou: 0.358]
#
# [Epoch 149/1000]  [time: 757.954s]  [lr = 0.04324343481952195]
# [train loss: 6.409]  [train miou: 0.423]  [valid loss: 6.948]  [valid miou: 0.399]
#
# [Epoch 150/1000]  [time: 757.397s]  [lr = 0.04319770934541793]
# [train loss: 6.388]  [train miou: 0.433]  [valid loss: 6.289]  [valid miou: 0.415]
#
# [Epoch 151/1000]  [time: 752.759s]  [lr = 0.04315197849152861]
# [train loss: 6.427]  [train miou: 0.429]  [valid loss: 6.712]  [valid miou: 0.387]
#
# [Epoch 152/1000]  [time: 758.358s]  [lr = 0.04310624225088331]
# [train loss: 6.429]  [train miou: 0.434]  [valid loss: 6.844]  [valid miou: 0.367]
#
# [Epoch 153/1000]  [time: 756.902s]  [lr = 0.043060500616494066]
# [train loss: 6.427]  [train miou: 0.435]  [valid loss: 7.453]  [valid miou: 0.371]
#
# [Epoch 154/1000]  [time: 758.469s]  [lr = 0.043014753581355605]
# [train loss: 6.505]  [train miou: 0.425]  [valid loss: 7.297]  [valid miou: 0.312]
#
# [Epoch 155/1000]  [time: 753.502s]  [lr = 0.042969001138445255]
# [train loss: 6.494]  [train miou: 0.418]  [valid loss: 6.621]  [valid miou: 0.398]
#
# [Epoch 156/1000]  [time: 756.582s]  [lr = 0.0429232432807229]
# [train loss: 6.436]  [train miou: 0.436]  [valid loss: 6.127]  [valid miou: 0.390]
#
# [Epoch 157/1000]  [time: 757.513s]  [lr = 0.042877480001130897]
# [train loss: 6.341]  [train miou: 0.435]  [valid loss: 6.662]  [valid miou: 0.397]
#
# [Epoch 158/1000]  [time: 755.987s]  [lr = 0.04283171129259402]
# [train loss: 6.379]  [train miou: 0.438]  [valid loss: 6.298]  [valid miou: 0.387]
#
# [Epoch 159/1000]  [time: 757.803s]  [lr = 0.0427859371480194]
# [train loss: 6.488]  [train miou: 0.431]  [valid loss: 6.833]  [valid miou: 0.381]
#
# [Epoch 160/1000]  [time: 756.374s]  [lr = 0.04274015756029645]
# [train loss: 6.352]  [train miou: 0.439]  [valid loss: 6.497]  [valid miou: 0.393]
#
# [Epoch 161/1000]  [time: 756.106s]  [lr = 0.04269437252229682]
# [train loss: 6.400]  [train miou: 0.433]  [valid loss: 6.683]  [valid miou: 0.398]
#
# [Epoch 162/1000]  [time: 756.259s]  [lr = 0.04264858202687429]
# [train loss: 6.375]  [train miou: 0.435]  [valid loss: 7.068]  [valid miou: 0.370]
#
# [Epoch 163/1000]  [time: 759.973s]  [lr = 0.04260278606686477]
# [train loss: 6.431]  [train miou: 0.435]  [valid loss: 6.727]  [valid miou: 0.376]
#
# [Epoch 164/1000]  [time: 754.877s]  [lr = 0.04255698463508615]
# [train loss: 6.401]  [train miou: 0.435]  [valid loss: 6.658]  [valid miou: 0.393]
#
# [Epoch 165/1000]  [time: 757.819s]  [lr = 0.042511177724338316]
# [train loss: 6.447]  [train miou: 0.427]  [valid loss: 6.524]  [valid miou: 0.402]
# [Epoch 166/1000]  [time: 754.917s]  [lr = 0.042465365327403026]
# [train loss: 6.415]  [train miou: 0.436]  [valid loss: 6.392]  [valid miou: 0.412]
#
# [Epoch 167/1000]  [time: 757.365s]  [lr = 0.042419547437043854]
# [train loss: 6.421]  [train miou: 0.430]  [valid loss: 6.857]  [valid miou: 0.405]
#
# [Epoch 168/1000]  [time: 756.194s]  [lr = 0.04237372404600615]
# [train loss: 6.367]  [train miou: 0.445]  [valid loss: 6.725]  [valid miou: 0.382]
#
# [Epoch 169/1000]  [time: 753.957s]  [lr = 0.04232789514701694]
# [train loss: 6.401]  [train miou: 0.428]  [valid loss: 6.229]  [valid miou: 0.405]
#
# [Epoch 170/1000]  [time: 754.586s]  [lr = 0.042282060732784864]
# [train loss: 6.448]  [train miou: 0.435]  [valid loss: 7.048]  [valid miou: 0.365]
#
# [Epoch 171/1000]  [time: 758.405s]  [lr = 0.04223622079600013]
# [train loss: 6.388]  [train miou: 0.435]  [valid loss: 6.600]  [valid miou: 0.367]
#
# [Epoch 172/1000]  [time: 756.583s]  [lr = 0.04219037532933442]
# [train loss: 6.372]  [train miou: 0.431]  [valid loss: 6.335]  [valid miou: 0.416]
#
# [Epoch 173/1000]  [time: 759.121s]  [lr = 0.04214452432544081]
# [train loss: 6.387]  [train miou: 0.436]  [valid loss: 6.984]  [valid miou: 0.379]
#
# [Epoch 174/1000]  [time: 756.554s]  [lr = 0.04209866777695375]
# [train loss: 6.382]  [train miou: 0.437]  [valid loss: 6.944]  [valid miou: 0.396]
#
# [Epoch 175/1000]  [time: 755.743s]  [lr = 0.04205280567648894]
# [train loss: 6.474]  [train miou: 0.428]  [valid loss: 6.877]  [valid miou: 0.376]
#
# [Epoch 176/1000]  [time: 756.252s]  [lr = 0.042006938016643305]
# [train loss: 6.384]  [train miou: 0.436]  [valid loss: 7.018]  [valid miou: 0.399]
#
# [Epoch 177/1000]  [time: 756.327s]  [lr = 0.04196106478999487]
# [train loss: 6.336]  [train miou: 0.440]  [valid loss: 6.872]  [valid miou: 0.390]
#
# [Epoch 178/1000]  [time: 753.913s]  [lr = 0.041915185989102745]
# [train loss: 6.378]  [train miou: 0.438]  [valid loss: 6.441]  [valid miou: 0.390]
#
# [Epoch 179/1000]  [time: 755.617s]  [lr = 0.04186930160650702]
# [train loss: 6.428]  [train miou: 0.426]  [valid loss: 6.713]  [valid miou: 0.411]
#
# [Epoch 180/1000]  [time: 756.197s]  [lr = 0.04182341163472871]
# [train loss: 6.405]  [train miou: 0.437]  [valid loss: 6.578]  [valid miou: 0.383]
#
# [Epoch 181/1000]  [time: 756.498s]  [lr = 0.04177751606626967]
# [train loss: 6.426]  [train miou: 0.440]  [valid loss: 6.249]  [valid miou: 0.401]
#
# [Epoch 182/1000]  [time: 757.430s]  [lr = 0.041731614893612524]
# [train loss: 6.473]  [train miou: 0.430]  [valid loss: 7.447]  [valid miou: 0.346]
#
# [Epoch 183/1000]  [time: 756.555s]  [lr = 0.0416857081092206]
# [train loss: 6.346]  [train miou: 0.433]  [valid loss: 6.168]  [valid miou: 0.381]
#
# [Epoch 184/1000]  [time: 757.108s]  [lr = 0.04163979570553786]
# [train loss: 6.391]  [train miou: 0.440]  [valid loss: 6.241]  [valid miou: 0.383]
#
# [Epoch 185/1000]  [time: 755.559s]  [lr = 0.041593877674988795]
# [train loss: 6.468]  [train miou: 0.436]  [valid loss: 6.487]  [valid miou: 0.426]
#
# [Epoch 186/1000]  [time: 756.772s]  [lr = 0.04154795400997841]
# [train loss: 6.356]  [train miou: 0.440]  [valid loss: 7.071]  [valid miou: 0.410]
#
# [Epoch 187/1000]  [time: 756.851s]  [lr = 0.04150202470289208]
# [train loss: 6.406]  [train miou: 0.438]  [valid loss: 6.586]  [valid miou: 0.387]
#
# [Epoch 188/1000]  [time: 756.295s]  [lr = 0.04145608974609555]
# [train loss: 6.353]  [train miou: 0.449]  [valid loss: 6.764]  [valid miou: 0.417]
#
# [Epoch 189/1000]  [time: 754.817s]  [lr = 0.04141014913193477]
# [train loss: 6.378]  [train miou: 0.446]  [valid loss: 7.528]  [valid miou: 0.380]
#
# [Epoch 190/1000]  [time: 757.549s]  [lr = 0.04136420285273591]
# [train loss: 6.420]  [train miou: 0.441]  [valid loss: 6.670]  [valid miou: 0.409]
#
# [Epoch 191/1000]  [time: 756.628s]  [lr = 0.04131825090080523]
# [train loss: 6.401]  [train miou: 0.434]  [valid loss: 6.095]  [valid miou: 0.411]
#
# [Epoch 192/1000]  [time: 755.560s]  [lr = 0.04127229326842902]
# [train loss: 6.404]  [train miou: 0.440]  [valid loss: 7.337]  [valid miou: 0.355]
#
# [Epoch 193/1000]  [time: 757.336s]  [lr = 0.0412263299478735]
# [train loss: 6.427]  [train miou: 0.432]  [valid loss: 6.623]  [valid miou: 0.392]
#
# [Epoch 194/1000]  [time: 756.604s]  [lr = 0.0411803609313848]
# [train loss: 6.414]  [train miou: 0.436]  [valid loss: 6.526]  [valid miou: 0.368]
#
# [Epoch 195/1000]  [time: 757.132s]  [lr = 0.04113438621118882]
# [train loss: 6.404]  [train miou: 0.451]  [valid loss: 6.765]  [valid miou: 0.436]
#
# [Epoch 196/1000]  [time: 760.955s]  [lr = 0.04108840577949119]
# [train loss: 6.463]  [train miou: 0.439]  [valid loss: 7.063]  [valid miou: 0.386]
#
# [Epoch 197/1000]  [time: 758.566s]  [lr = 0.04104241962847717]
# [train loss: 6.336]  [train miou: 0.448]  [valid loss: 6.568]  [valid miou: 0.405]
#
# [Epoch 198/1000]  [time: 754.523s]  [lr = 0.0409964277503116]
# [train loss: 6.379]  [train miou: 0.446]  [valid loss: 6.669]  [valid miou: 0.388]
#
# [Epoch 199/1000]  [time: 757.197s]  [lr = 0.04095043013713877]
# [train loss: 6.392]  [train miou: 0.442]  [valid loss: 6.968]  [valid miou: 0.387]
#
# [Epoch 200/1000]  [time: 758.791s]  [lr = 0.040904426781082415]
# [train loss: 6.421]  [train miou: 0.443]  [valid loss: 6.921]  [valid miou: 0.295]
#
# [Epoch 201/1000]  [time: 763.511s]  [lr = 0.040858417674245556]
# [train loss: 6.398]  [train miou: 0.439]  [valid loss: 6.458]  [valid miou: 0.387]
#
# [Epoch 202/1000]  [time: 757.809s]  [lr = 0.04081240280871049]
# [train loss: 6.373]  [train miou: 0.440]  [valid loss: 6.457]  [valid miou: 0.425]
#
# [Epoch 203/1000]  [time: 758.947s]  [lr = 0.04076638217653864]
# [train loss: 6.347]  [train miou: 0.448]  [valid loss: 6.799]  [valid miou: 0.350]
#
# [Epoch 204/1000]  [time: 759.592s]  [lr = 0.04072035576977056]
# [train loss: 6.403]  [train miou: 0.442]  [valid loss: 6.484]  [valid miou: 0.421]
#
# [Epoch 205/1000]  [time: 756.981s]  [lr = 0.040674323580425754]
# [train loss: 6.370]  [train miou: 0.441]  [valid loss: 6.411]  [valid miou: 0.436]
#
# [Epoch 206/1000]  [time: 758.318s]  [lr = 0.04062828560050267]
# [train loss: 6.412]  [train miou: 0.445]  [valid loss: 6.351]  [valid miou: 0.414]
#
# [Epoch 207/1000]  [time: 759.193s]  [lr = 0.040582241821978574]
# [train loss: 6.387]  [train miou: 0.444]  [valid loss: 7.058]  [valid miou: 0.387]
#
# [Epoch 208/1000]  [time: 759.762s]  [lr = 0.04053619223680952]
# [train loss: 6.344]  [train miou: 0.446]  [valid loss: 6.885]  [valid miou: 0.409]
#
# [Epoch 209/1000]  [time: 759.407s]  [lr = 0.040490136836930195]
# [train loss: 6.360]  [train miou: 0.444]  [valid loss: 6.853]  [valid miou: 0.386]
#
# [Epoch 210/1000]  [time: 761.328s]  [lr = 0.040444075614253894]
# [train loss: 6.375]  [train miou: 0.441]  [valid loss: 6.172]  [valid miou: 0.398]
#
# [Epoch 211/1000]  [time: 762.188s]  [lr = 0.040398008560672403]
# [train loss: 6.341]  [train miou: 0.446]  [valid loss: 6.989]  [valid miou: 0.379]
#
# [Epoch 212/1000]  [time: 757.749s]  [lr = 0.040351935668055935]
# [train loss: 6.415]  [train miou: 0.440]  [valid loss: 6.402]  [valid miou: 0.415]
#
# [Epoch 213/1000]  [time: 756.753s]  [lr = 0.04030585692825303]
# [train loss: 6.318]  [train miou: 0.453]  [valid loss: 6.716]  [valid miou: 0.385]
#
# [Epoch 214/1000]  [time: 760.000s]  [lr = 0.040259772333090464]
# [train loss: 6.350]  [train miou: 0.444]  [valid loss: 6.173]  [valid miou: 0.416]
#
# [Epoch 215/1000]  [time: 757.167s]  [lr = 0.040213681874373214]
# [train loss: 6.364]  [train miou: 0.447]  [valid loss: 6.248]  [valid miou: 0.388]
#
# [Epoch 216/1000]  [time: 758.536s]  [lr = 0.040167585543884284]
# [train loss: 6.411]  [train miou: 0.448]  [valid loss: 5.980]  [valid miou: 0.424]
#
# [Epoch 217/1000]  [time: 759.385s]  [lr = 0.040121483333384694]
# [train loss: 6.293]  [train miou: 0.457]  [valid loss: 5.982]  [valid miou: 0.430]
#
# [Epoch 218/1000]  [time: 758.754s]  [lr = 0.04007537523461337]
# [train loss: 6.322]  [train miou: 0.450]  [valid loss: 6.503]  [valid miou: 0.408]
#
# [Epoch 219/1000]  [time: 756.561s]  [lr = 0.04002926123928703]
# [train loss: 6.380]  [train miou: 0.445]  [valid loss: 6.581]  [valid miou: 0.409]
#
# [Epoch 220/1000]  [time: 760.555s]  [lr = 0.039983141339100144]
# [train loss: 6.358]  [train miou: 0.446]  [valid loss: 7.279]  [valid miou: 0.334]
#
# [Epoch 221/1000]  [time: 756.583s]  [lr = 0.03993701552572478]
# [train loss: 6.368]  [train miou: 0.447]  [valid loss: 7.220]  [valid miou: 0.373]
# [Epoch 222/1000]  [time: 772.775s]  [lr = 0.03989088379081062]
# [train loss: 6.350]  [train miou: 0.444]  [valid loss: 6.737]  [valid miou: 0.379]
#
# [Epoch 223/1000]  [time: 772.526s]  [lr = 0.03984474612598474]
# [train loss: 6.398]  [train miou: 0.443]  [valid loss: 6.130]  [valid miou: 0.398]
#
# [Epoch 224/1000]  [time: 758.412s]  [lr = 0.039798602522851605]
# [train loss: 6.373]  [train miou: 0.453]  [valid loss: 6.344]  [valid miou: 0.400]
#
# [Epoch 225/1000]  [time: 759.722s]  [lr = 0.039752452972992985]
# [train loss: 6.410]  [train miou: 0.447]  [valid loss: 6.557]  [valid miou: 0.387]
#
# [Epoch 226/1000]  [time: 759.348s]  [lr = 0.0397062974679678]
# [train loss: 6.379]  [train miou: 0.446]  [valid loss: 6.297]  [valid miou: 0.347]
#
# [Epoch 227/1000]  [time: 757.779s]  [lr = 0.03966013599931209]
# [train loss: 6.379]  [train miou: 0.448]  [valid loss: 6.095]  [valid miou: 0.441]
#
# [Epoch 228/1000]  [time: 763.425s]  [lr = 0.0396139685585389]
# [train loss: 6.328]  [train miou: 0.452]  [valid loss: 6.731]  [valid miou: 0.410]
#
# [Epoch 229/1000]  [time: 767.374s]  [lr = 0.03956779513713818]
# [train loss: 6.378]  [train miou: 0.448]  [valid loss: 6.998]  [valid miou: 0.422]
#
# [Epoch 230/1000]  [time: 776.710s]  [lr = 0.03952161572657668]
# [train loss: 6.326]  [train miou: 0.456]  [valid loss: 6.841]  [valid miou: 0.444]
#
# [Epoch 231/1000]  [time: 771.541s]  [lr = 0.03947543031829791]
# [train loss: 6.371]  [train miou: 0.452]  [valid loss: 6.730]  [valid miou: 0.388]
#
# [Epoch 232/1000]  [time: 765.331s]  [lr = 0.039429238903722005]
# [train loss: 6.432]  [train miou: 0.446]  [valid loss: 8.092]  [valid miou: 0.355]
#
# [Epoch 233/1000]  [time: 768.252s]  [lr = 0.039383041474245616]
# [train loss: 6.347]  [train miou: 0.443]  [valid loss: 6.770]  [valid miou: 0.395]
#
# [Epoch 234/1000]  [time: 771.577s]  [lr = 0.03933683802124186]
# [train loss: 6.380]  [train miou: 0.450]  [valid loss: 6.779]  [valid miou: 0.397]
#
# [Epoch 235/1000]  [time: 776.166s]  [lr = 0.03929062853606019]
# [train loss: 6.399]  [train miou: 0.445]  [valid loss: 6.470]  [valid miou: 0.402]
#
# [Epoch 236/1000]  [time: 754.471s]  [lr = 0.039244413010026326]
# [train loss: 6.335]  [train miou: 0.456]  [valid loss: 6.422]  [valid miou: 0.418]
#
# [Epoch 237/1000]  [time: 755.629s]  [lr = 0.03919819143444211]
# [train loss: 6.297]  [train miou: 0.458]  [valid loss: 6.960]  [valid miou: 0.389]
#
# [Epoch 238/1000]  [time: 755.703s]  [lr = 0.03915196380058548]
# [train loss: 6.369]  [train miou: 0.444]  [valid loss: 6.416]  [valid miou: 0.403]
#
# [Epoch 239/1000]  [time: 756.837s]  [lr = 0.039105730099710315]
# [train loss: 6.333]  [train miou: 0.454]  [valid loss: 6.086]  [valid miou: 0.426]
#
# [Epoch 240/1000]  [time: 789.151s]  [lr = 0.039059490323046356]
# [train loss: 6.398]  [train miou: 0.447]  [valid loss: 6.990]  [valid miou: 0.307]
#
# [Epoch 241/1000]  [time: 773.354s]  [lr = 0.03901324446179913]
# [train loss: 6.336]  [train miou: 0.445]  [valid loss: 6.877]  [valid miou: 0.401]
#
# [Epoch 242/1000]  [time: 758.195s]  [lr = 0.03896699250714981]
# [train loss: 6.387]  [train miou: 0.449]  [valid loss: 6.470]  [valid miou: 0.404]
#
# [Epoch 243/1000]  [time: 759.138s]  [lr = 0.03892073445025512]
# [train loss: 6.362]  [train miou: 0.456]  [valid loss: 6.232]  [valid miou: 0.421]
#
# [Epoch 244/1000]  [time: 763.320s]  [lr = 0.03887447028224729]
# [train loss: 6.257]  [train miou: 0.464]  [valid loss: 6.616]  [valid miou: 0.426]
#
# [Epoch 245/1000]  [time: 763.586s]  [lr = 0.03882819999423389]
# [train loss: 6.293]  [train miou: 0.464]  [valid loss: 6.631]  [valid miou: 0.426]
#
# [Epoch 246/1000]  [time: 762.621s]  [lr = 0.03878192357729777]
# [train loss: 6.355]  [train miou: 0.449]  [valid loss: 6.437]  [valid miou: 0.420]
#
# [Epoch 247/1000]  [time: 757.332s]  [lr = 0.03873564102249691]
# [train loss: 6.314]  [train miou: 0.450]  [valid loss: 6.476]  [valid miou: 0.393]
#
# [Epoch 248/1000]  [time: 757.309s]  [lr = 0.03868935232086439]
# [train loss: 6.326]  [train miou: 0.456]  [valid loss: 6.585]  [valid miou: 0.396]
#
# [Epoch 249/1000]  [time: 762.179s]  [lr = 0.03864305746340822]
# [train loss: 6.347]  [train miou: 0.460]  [valid loss: 6.452]  [valid miou: 0.429]
#
# [Epoch 250/1000]  [time: 876.382s]  [lr = 0.03859675644111129]
# [train loss: 6.385]  [train miou: 0.457]  [valid loss: 6.439]  [valid miou: 0.423]
#
# [Epoch 251/1000]  [time: 782.905s]  [lr = 0.038550449244931215]
# [train loss: 6.364]  [train miou: 0.453]  [valid loss: 6.887]  [valid miou: 0.412]
#
# [Epoch 252/1000]  [time: 767.421s]  [lr = 0.03850413586580027]
# [train loss: 6.387]  [train miou: 0.454]  [valid loss: 6.827]  [valid miou: 0.414]
#
# [Epoch 253/1000]  [time: 769.494s]  [lr = 0.038457816294625254]
# [train loss: 6.323]  [train miou: 0.448]  [valid loss: 6.557]  [valid miou: 0.431]
#
# [Epoch 254/1000]  [time: 755.568s]  [lr = 0.038411490522287435]
# [train loss: 6.328]  [train miou: 0.452]  [valid loss: 7.036]  [valid miou: 0.395]
#
# [Epoch 255/1000]  [time: 760.205s]  [lr = 0.03836515853964237]
# [train loss: 6.383]  [train miou: 0.449]  [valid loss: 6.726]  [valid miou: 0.383]
#
# [Epoch 256/1000]  [time: 760.756s]  [lr = 0.03831882033751987]
# [train loss: 6.336]  [train miou: 0.456]  [valid loss: 7.108]  [valid miou: 0.382]
#
# [Epoch 257/1000]  [time: 765.612s]  [lr = 0.03827247590672384]
# [train loss: 6.318]  [train miou: 0.463]  [valid loss: 6.612]  [valid miou: 0.398]
#
# [Epoch 258/1000]  [time: 765.776s]  [lr = 0.03822612523803221]
# [train loss: 6.358]  [train miou: 0.456]  [valid loss: 6.839]  [valid miou: 0.413]
#
# [Epoch 259/1000]  [time: 765.122s]  [lr = 0.038179768322196786]
# [train loss: 6.324]  [train miou: 0.459]  [valid loss: 6.436]  [valid miou: 0.413]
#
# [Epoch 260/1000]  [time: 765.347s]  [lr = 0.03813340514994318]
# [train loss: 6.332]  [train miou: 0.454]  [valid loss: 6.701]  [valid miou: 0.421]
#
# [Epoch 261/1000]  [time: 769.961s]  [lr = 0.03808703571197066]
# [train loss: 6.364]  [train miou: 0.453]  [valid loss: 6.723]  [valid miou: 0.391]
#
# [Epoch 262/1000]  [time: 759.151s]  [lr = 0.03804065999895211]
# [train loss: 6.293]  [train miou: 0.460]  [valid loss: 6.518]  [valid miou: 0.430]
#
# [Epoch 263/1000]  [time: 768.399s]  [lr = 0.037994278001533814]
# [train loss: 6.309]  [train miou: 0.458]  [valid loss: 6.443]  [valid miou: 0.409]
#
# [Epoch 264/1000]  [time: 764.559s]  [lr = 0.03794788971033544]
# [train loss: 6.405]  [train miou: 0.446]  [valid loss: 7.010]  [valid miou: 0.412]
#
# [Epoch 265/1000]  [time: 768.212s]  [lr = 0.03790149511594989]
# [train loss: 6.331]  [train miou: 0.461]  [valid loss: 7.048]  [valid miou: 0.414]
#
# [Epoch 266/1000]  [time: 769.934s]  [lr = 0.037855094208943146]
# [train loss: 6.408]  [train miou: 0.458]  [valid loss: 6.812]  [valid miou: 0.430]
#
# [Epoch 267/1000]  [time: 771.386s]  [lr = 0.037808686979854254]
# [train loss: 6.333]  [train miou: 0.460]  [valid loss: 7.120]  [valid miou: 0.417]
#
# [Epoch 268/1000]  [time: 774.755s]  [lr = 0.03776227341919511]
# [train loss: 6.317]  [train miou: 0.467]  [valid loss: 6.528]  [valid miou: 0.421]
#
# [Epoch 269/1000]  [time: 776.562s]  [lr = 0.03771585351745041]
# [train loss: 6.313]  [train miou: 0.457]  [valid loss: 7.573]  [valid miou: 0.399]
#
# [Epoch 270/1000]  [time: 775.504s]  [lr = 0.03766942726507749]
# [train loss: 6.312]  [train miou: 0.460]  [valid loss: 6.731]  [valid miou: 0.444]
#
# [Epoch 271/1000]  [time: 773.627s]  [lr = 0.03762299465250628]
# [train loss: 6.294]  [train miou: 0.459]  [valid loss: 7.366]  [valid miou: 0.340]
#
# [Epoch 272/1000]  [time: 776.154s]  [lr = 0.03757655567013908]
# [train loss: 6.349]  [train miou: 0.454]  [valid loss: 6.431]  [valid miou: 0.426]
#
# [Epoch 273/1000]  [time: 772.935s]  [lr = 0.037530110308350545]
# [train loss: 6.278]  [train miou: 0.464]  [valid loss: 6.781]  [valid miou: 0.397]
#
# [Epoch 274/1000]  [time: 776.968s]  [lr = 0.03748365855748751]
# [train loss: 6.369]  [train miou: 0.460]  [valid loss: 6.981]  [valid miou: 0.412]
#
# [Epoch 275/1000]  [time: 781.152s]  [lr = 0.03743720040786888]
# [train loss: 6.389]  [train miou: 0.447]  [valid loss: 7.089]  [valid miou: 0.351]
#
# [Epoch 276/1000]  [time: 780.493s]  [lr = 0.03739073584978553]
# [train loss: 6.412]  [train miou: 0.447]  [valid loss: 6.336]  [valid miou: 0.407]
#
# [Epoch 277/1000]  [time: 774.427s]  [lr = 0.037344264873500156]
# [train loss: 6.288]  [train miou: 0.461]  [valid loss: 6.828]  [valid miou: 0.389]
# [Epoch 278/1000]  [time: 774.346s]  [lr = 0.03729778746924719]
# [train loss: 6.363]  [train miou: 0.461]  [valid loss: 6.808]  [valid miou: 0.405]
#
# [Epoch 279/1000]  [time: 774.525s]  [lr = 0.037251303627232626]
# [train loss: 6.281]  [train miou: 0.469]  [valid loss: 6.512]  [valid miou: 0.403]
#
# [Epoch 280/1000]  [time: 776.403s]  [lr = 0.03720481333763396]
# [train loss: 6.347]  [train miou: 0.460]  [valid loss: 6.646]  [valid miou: 0.427]
#
# [Epoch 281/1000]  [time: 775.348s]  [lr = 0.03715831659060003]
# [train loss: 6.285]  [train miou: 0.461]  [valid loss: 7.240]  [valid miou: 0.387]
#
# [Epoch 282/1000]  [time: 764.800s]  [lr = 0.037111813376250885]
# [train loss: 6.426]  [train miou: 0.458]  [valid loss: 6.369]  [valid miou: 0.409]
#
# [Epoch 283/1000]  [time: 759.890s]  [lr = 0.037065303684677704]
# [train loss: 6.341]  [train miou: 0.461]  [valid loss: 6.723]  [valid miou: 0.386]
#
# [Epoch 284/1000]  [time: 763.188s]  [lr = 0.03701878750594259]
# [train loss: 6.361]  [train miou: 0.457]  [valid loss: 6.126]  [valid miou: 0.416]
#
# [Epoch 285/1000]  [time: 762.215s]  [lr = 0.03697226483007857]
# [train loss: 6.283]  [train miou: 0.465]  [valid loss: 7.161]  [valid miou: 0.418]
#
# [Epoch 286/1000]  [time: 767.341s]  [lr = 0.03692573564708933]
# [train loss: 6.337]  [train miou: 0.460]  [valid loss: 7.134]  [valid miou: 0.329]
#
# [Epoch 287/1000]  [time: 767.358s]  [lr = 0.03687919994694919]
# [train loss: 6.265]  [train miou: 0.464]  [valid loss: 6.335]  [valid miou: 0.427]
#
# [Epoch 288/1000]  [time: 770.922s]  [lr = 0.0368326577196029]
# [train loss: 6.321]  [train miou: 0.465]  [valid loss: 7.054]  [valid miou: 0.387]
#
# [Epoch 289/1000]  [time: 772.964s]  [lr = 0.036786108954965625]
# [train loss: 6.352]  [train miou: 0.455]  [valid loss: 6.976]  [valid miou: 0.404]
#
# [Epoch 290/1000]  [time: 775.418s]  [lr = 0.03673955364292266]
# [train loss: 6.382]  [train miou: 0.460]  [valid loss: 7.407]  [valid miou: 0.404]
#
# [Epoch 291/1000]  [time: 777.961s]  [lr = 0.036692991773329436]
# [train loss: 6.307]  [train miou: 0.465]  [valid loss: 6.674]  [valid miou: 0.429]
#
# [Epoch 292/1000]  [time: 779.909s]  [lr = 0.03664642333601129]
# [train loss: 6.308]  [train miou: 0.465]  [valid loss: 6.484]  [valid miou: 0.419]
#
# [Epoch 293/1000]  [time: 780.377s]  [lr = 0.036599848320763434]
# [train loss: 6.271]  [train miou: 0.465]  [valid loss: 6.933]  [valid miou: 0.432]
#
# [Epoch 294/1000]  [time: 777.386s]  [lr = 0.03655326671735071]
# [train loss: 6.306]  [train miou: 0.465]  [valid loss: 6.854]  [valid miou: 0.401]
#
# [Epoch 295/1000]  [time: 776.161s]  [lr = 0.03650667851550755]
# [train loss: 6.310]  [train miou: 0.471]  [valid loss: 6.890]  [valid miou: 0.410]
#
# [Epoch 296/1000]  [time: 774.612s]  [lr = 0.03646008370493778]
# [train loss: 6.309]  [train miou: 0.464]  [valid loss: 6.826]  [valid miou: 0.420]
#
# [Epoch 297/1000]  [time: 774.520s]  [lr = 0.036413482275314546]
# [train loss: 6.297]  [train miou: 0.460]  [valid loss: 7.322]  [valid miou: 0.350]
#
# [Epoch 298/1000]  [time: 774.508s]  [lr = 0.0363668742162801]
# [train loss: 6.403]  [train miou: 0.452]  [valid loss: 6.919]  [valid miou: 0.383]
#
# [Epoch 299/1000]  [time: 771.816s]  [lr = 0.03632025951744575]
# [train loss: 6.349]  [train miou: 0.459]  [valid loss: 6.689]  [valid miou: 0.396]
#
# [Epoch 300/1000]  [time: 772.174s]  [lr = 0.036273638168391624]
# [train loss: 6.288]  [train miou: 0.467]  [valid loss: 6.502]  [valid miou: 0.405]
#
# [Epoch 301/1000]  [time: 775.545s]  [lr = 0.03622701015866667]
# [train loss: 6.263]  [train miou: 0.469]  [valid loss: 6.718]  [valid miou: 0.427]
#
# [Epoch 302/1000]  [time: 774.389s]  [lr = 0.03618037547778835]
# [train loss: 6.377]  [train miou: 0.456]  [valid loss: 7.015]  [valid miou: 0.424]
#
# [Epoch 303/1000]  [time: 774.143s]  [lr = 0.03613373411524265]
# [train loss: 6.345]  [train miou: 0.465]  [valid loss: 6.690]  [valid miou: 0.437]
#
# [Epoch 304/1000]  [time: 775.129s]  [lr = 0.03608708606048383]
# [train loss: 6.323]  [train miou: 0.462]  [valid loss: 7.336]  [valid miou: 0.423]
#
# [Epoch 305/1000]  [time: 768.177s]  [lr = 0.03604043130293437]
# [train loss: 6.283]  [train miou: 0.470]  [valid loss: 7.382]  [valid miou: 0.395]
#
# [Epoch 306/1000]  [time: 771.712s]  [lr = 0.03599376983198475]
# [train loss: 6.316]  [train miou: 0.464]  [valid loss: 6.288]  [valid miou: 0.446]
#
# [Epoch 307/1000]  [time: 773.602s]  [lr = 0.03594710163699337]
# [train loss: 6.272]  [train miou: 0.473]  [valid loss: 7.163]  [valid miou: 0.419]
#
# [Epoch 308/1000]  [time: 775.929s]  [lr = 0.03590042670728636]
# [train loss: 6.320]  [train miou: 0.467]  [valid loss: 6.292]  [valid miou: 0.424]
#
# [Epoch 309/1000]  [time: 778.980s]  [lr = 0.035853745032157484]
# [train loss: 6.277]  [train miou: 0.467]  [valid loss: 6.551]  [valid miou: 0.426]
#
# [Epoch 310/1000]  [time: 778.371s]  [lr = 0.035807056600867915]
# [train loss: 6.400]  [train miou: 0.426]  [valid loss: 6.355]  [valid miou: 0.398]
#
# [Epoch 311/1000]  [time: 778.387s]  [lr = 0.03576036140264621]
# [train loss: 6.305]  [train miou: 0.461]  [valid loss: 6.858]  [valid miou: 0.418]
#
# [Epoch 312/1000]  [time: 778.573s]  [lr = 0.03571365942668804]
# [train loss: 6.328]  [train miou: 0.463]  [valid loss: 6.593]  [valid miou: 0.454]
#
# [Epoch 313/1000]  [time: 781.736s]  [lr = 0.035666950662156124]
# [train loss: 6.282]  [train miou: 0.464]  [valid loss: 6.364]  [valid miou: 0.415]
#
# [Epoch 314/1000]  [time: 782.334s]  [lr = 0.03562023509818002]
# [train loss: 6.311]  [train miou: 0.467]  [valid loss: 6.237]  [valid miou: 0.443]
#
# [Epoch 315/1000]  [time: 783.347s]  [lr = 0.035573512723856046]
# [train loss: 6.358]  [train miou: 0.454]  [valid loss: 6.557]  [valid miou: 0.441]
#
# [Epoch 316/1000]  [time: 783.623s]  [lr = 0.035526783528247056]
# [train loss: 6.326]  [train miou: 0.463]  [valid loss: 6.215]  [valid miou: 0.428]
#
# [Epoch 317/1000]  [time: 781.900s]  [lr = 0.035480047500382354]
# [train loss: 6.246]  [train miou: 0.468]  [valid loss: 6.597]  [valid miou: 0.434]
#
# [Epoch 318/1000]  [time: 786.940s]  [lr = 0.03543330462925747]
# [train loss: 6.262]  [train miou: 0.467]  [valid loss: 6.189]  [valid miou: 0.445]
#
# [Epoch 319/1000]  [time: 778.369s]  [lr = 0.035386554903834105]
# [train loss: 6.347]  [train miou: 0.462]  [valid loss: 6.673]  [valid miou: 0.413]
#
# [Epoch 320/1000]  [time: 776.006s]  [lr = 0.03533979831303984]
# [train loss: 6.330]  [train miou: 0.460]  [valid loss: 6.658]  [valid miou: 0.431]
#
# [Epoch 321/1000]  [time: 778.357s]  [lr = 0.03529303484576815]
# [train loss: 6.304]  [train miou: 0.465]  [valid loss: 6.888]  [valid miou: 0.386]
#
# [Epoch 322/1000]  [time: 780.164s]  [lr = 0.035246264490878074]
# [train loss: 6.339]  [train miou: 0.459]  [valid loss: 6.688]  [valid miou: 0.416]
#
# [Epoch 323/1000]  [time: 781.585s]  [lr = 0.0351994872371942]
# [train loss: 6.286]  [train miou: 0.475]  [valid loss: 6.568]  [valid miou: 0.411]
#
# [Epoch 324/1000]  [time: 766.299s]  [lr = 0.0351527030735064]
# [train loss: 6.283]  [train miou: 0.468]  [valid loss: 6.800]  [valid miou: 0.428]
#
# [Epoch 325/1000]  [time: 759.645s]  [lr = 0.035105911988569785]
# [train loss: 6.322]  [train miou: 0.457]  [valid loss: 7.151]  [valid miou: 0.395]
#
# [Epoch 326/1000]  [time: 760.928s]  [lr = 0.0350591139711044]
# [train loss: 6.309]  [train miou: 0.472]  [valid loss: 6.339]  [valid miou: 0.440]
#
# [Epoch 327/1000]  [time: 760.350s]  [lr = 0.03501230900979521]
# [train loss: 6.318]  [train miou: 0.467]  [valid loss: 7.037]  [valid miou: 0.411]
#
# [Epoch 328/1000]  [time: 759.791s]  [lr = 0.03496549709329182]
# [train loss: 6.262]  [train miou: 0.465]  [valid loss: 6.147]  [valid miou: 0.421]
#
# [Epoch 329/1000]  [time: 766.129s]  [lr = 0.034918678210208394]
# [train loss: 6.340]  [train miou: 0.462]  [valid loss: 6.962]  [valid miou: 0.376]
#
# [Epoch 330/1000]  [time: 759.206s]  [lr = 0.03487185234912345]
# [train loss: 6.383]  [train miou: 0.473]  [valid loss: 6.798]  [valid miou: 0.435]
#
# [Epoch 331/1000]  [time: 758.556s]  [lr = 0.034825019498579704]
# [train loss: 6.282]  [train miou: 0.461]  [valid loss: 6.165]  [valid miou: 0.440]
#
# [Epoch 332/1000]  [time: 759.734s]  [lr = 0.03477817964708389]
# [train loss: 6.283]  [train miou: 0.470]  [valid loss: 6.327]  [valid miou: 0.428]
#
# [Epoch 333/1000]  [time: 757.203s]  [lr = 0.03473133278310666]
# [train loss: 6.335]  [train miou: 0.459]  [valid loss: 6.613]  [valid miou: 0.423]
# [Epoch 334/1000]  [time: 756.176s]  [lr = 0.034684478895082284]
# [train loss: 6.322]  [train miou: 0.461]  [valid loss: 6.550]  [valid miou: 0.412]
#
# [Epoch 335/1000]  [time: 761.184s]  [lr = 0.03463761797140863]
# [train loss: 6.285]  [train miou: 0.465]  [valid loss: 6.706]  [valid miou: 0.418]
#
# [Epoch 336/1000]  [time: 762.931s]  [lr = 0.034590750000446875]
# [train loss: 6.299]  [train miou: 0.470]  [valid loss: 6.306]  [valid miou: 0.427]
#
# [Epoch 337/1000]  [time: 764.157s]  [lr = 0.03454387497052144]
# [train loss: 6.301]  [train miou: 0.465]  [valid loss: 6.428]  [valid miou: 0.402]

# %%
# check losses and miou scores graph
fig, ax = plt.subplots(1,2, figsize=(20,10))
ax[0].set_title('Loss Graph', fontsize=20)
ax[0].plot(np.arange(len(history['loss'])), history['loss'], label='Train Loss')
ax[0].plot(np.arange(len(history['val_loss'])), history['val_loss'], label='Valid Loss')
ax[0].set_ylim(0,10)
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend(loc='best')
ax[1].set_title('mIoU Score Graph', fontsize=20)
ax[1].plot(np.arange(len(history['miou'])), history['miou'], label='Train mIoU')
ax[1].plot(np.arange(len(history['val_miou'])), history['val_miou'], label='Valid mIoU')
ax[1].set_ylim(0,1)
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('mIoU')
ax[1].legend(loc='best')
fig.show()

# %% [markdown]
# # test model

# %%
# load test data
test_augment = A.Compose([
    A.Resize(height=height//2,
             width=width//2)
])

train_loader = DataLoader(
    CityscapesDataset(path=path, subset='train', cropsize=(width,height)),
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

test_loader = DataLoader(
    CityscapesDataset(path=path, subset='test'),
    batch_size=batch_size,
    shuffle=False,
    drop_last=True,
)

# %%
# test
test_images_list = []
test_outputs_list = []

model.eval()
with torch.no_grad():
    tbatch_loss, tbatch_miou = 0, 0
    for tbatch, test_images in enumerate(test_loader):
        test_images = test_images.to(device)
        # predict
        test_outputs, _, _, _, _ = model(test_images)
        
        test_images_list.append(test_images.detach().cpu())
        test_outputs_list.append(test_outputs.detach().cpu())
        
        del test_images; del test_outputs
    
test_images = torch.cat(test_images_list, dim=0)
del test_images_list
test_outputs = torch.cat(test_outputs_list, dim=0)
del test_outputs_list

# %%
# 12 classes channels to 3 RGB channels
def map_class_to_rgb(p):
    return rgb_array[p[0]]

def mask2rgb(images):
    rgb_img_list = []
    for img in tqdm(images):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1,2,0))
        img = np.argmax(img, axis=-1)
        rgb_img = np.apply_along_axis(map_class_to_rgb, -1, np.expand_dims(img, -1))
        rgb_img_list.append(rgb_img)
    return np.array(rgb_img_list)

test_result = mask2rgb(test_outputs)
del test_outputs

# %%
# show test outputs with miou score
def cuda2numpy(tensors):
    tensors = tensors.detach().cpu().numpy()
    return np.transpose(tensors, (0,2,3,1))

def show_result(input_image, pred_image, ncols):
    input_image = cuda2numpy(input_image)
    for i in range(ncols):
        # plot images
        fig, ax = plt.subplots(1,2, figsize=(20,10))
        ax[0].imshow(input_image[i])
        ax[0].axis('off')
        ax[0].set_title('Input Image')
        ax[1].imshow(pred_image[i])
        ax[1].axis('off')
        ax[1].set_title(f'Preditect Image')
        fig.show()

show_result(test_images, test_result, 20)

# %%
model = BiSeNetV2(input_size=(height//2,width//2), bga_size=(height//16,width//16), phase='train').to(device)
model.load_state_dict(torch.load('./model/cp_checkpoint.pt'))

# %%
# test
test_images_list = []
test_outputs_list = []

model.eval()
with torch.no_grad():
    tbatch_loss, tbatch_miou = 0, 0
    for tbatch, test_images in enumerate(test_loader):
        test_images = test_images.to(device)
        # predict
        test_outputs, _, _, _, _ = model(test_images)
        
        test_images_list.append(test_images.detach().cpu())
        test_outputs_list.append(test_outputs.detach().cpu())
        
        del test_images; del test_outputs
    
test_images = torch.cat(test_images_list, dim=0)
del test_images_list
test_outputs = torch.cat(test_outputs_list, dim=0)
del test_outputs_list

# %%
test_result = mask2rgb(test_outputs)
del test_outputs

# %%
show_result(test_images, test_result, 70)

# %%
import torch
import math

class WarmupLrScheduler(torch.optim.lr_scheduler._LRScheduler):

    def __init__(
            self,
            optimizer,
            warmup_iter=500,
            warmup_ratio=5e-4,
            warmup='exp',
            last_epoch=-1,
    ):
        self.warmup_iter = warmup_iter
        self.warmup_ratio = warmup_ratio
        self.warmup = warmup
        super(WarmupLrScheduler, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        ratio = self.get_lr_ratio()
        lrs = [ratio * lr for lr in self.base_lrs]
        return lrs

    def get_lr_ratio(self):
        if self.last_epoch < self.warmup_iter:
            ratio = self.get_warmup_ratio()
        else:
            ratio = self.get_main_ratio()
        return ratio

    def get_main_ratio(self):
        raise NotImplementedError

    def get_warmup_ratio(self):
        assert self.warmup in ('linear', 'exp')
        alpha = self.last_epoch / self.warmup_iter
        if self.warmup == 'linear':
            ratio = self.warmup_ratio + (1 - self.warmup_ratio) * alpha
        elif self.warmup == 'exp':
            ratio = self.warmup_ratio ** (1. - alpha)
        return ratio


class WarmupPolyLrScheduler(WarmupLrScheduler):

    def __init__(
            self,
            optimizer,
            power,
            max_iter,
            warmup_iter=500,
            warmup_ratio=5e-4,
            warmup='exp',
            last_epoch=-1,
    ):
        self.power = power
        self.max_iter = max_iter
        super(WarmupPolyLrScheduler, self).__init__(
            optimizer, warmup_iter, warmup_ratio, warmup, last_epoch)

    def get_main_ratio(self):
        real_iter = self.last_epoch - self.warmup_iter
        real_max_iter = self.max_iter - self.warmup_iter
        alpha = real_iter / real_max_iter
        ratio = (1 - alpha) ** self.power
        return ratio

# %%
import matplotlib.pyplot as plt

model = torch.nn.Linear(2, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
scheduler = WarmupPolyLrScheduler(optimizer=optimizer,
                                  power=0.9, max_iter=100)


lrs = []

for i in range(100):
    optimizer.step()
    lrs.append(optimizer.param_groups[0]["lr"])
#     print("Factor = ", round(0.65 ** i,3)," , Learning Rate = ",round(optimizer.param_groups[0]["lr"],3))
    scheduler.step()

plt.plot(range(100),lrs)
